# %% [markdown]
# ## Collecting data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

# %%
plt.figure(figsize=(10,8))
sns.heatmap(train.corr(),cmap='coolwarm',annot=True)
# Out:
# C:\Users\ivanv\AppData\Local\Temp\ipykernel_3928\165970561.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(),cmap='coolwarm',annot=True)
# <Axes: >

# %%
plt.figure(figsize=(10,8))
sns.heatmap(test.corr(),cmap='coolwarm',annot=True)
# Out:
# C:\Users\ivanv\AppData\Local\Temp\ipykernel_3928\3083444607.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(test.corr(),cmap='coolwarm',annot=True)
# <Axes: >

# %% [markdown]
# ## Data analysis

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %% [markdown]
# ### Data Dictionary
# - Survived: 	0 = No, 1 = Yes
# - pclass: 	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp:	# of siblings / spouses aboard the Titanic
# - parch:	# of parents / children aboard the Titanic
# - ticket:	Ticket number
# - cabin:	Cabin number
# - embarked:	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# **Total rows and columns**
#
# We can see that there are 891 rows and 12 columns in our training dataset.

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# We can see that Age value is missing for many rows.
#
# Out of 891 rows, the Age value is present only in 714 rows.
#
# Similarly, Cabin values are also missing in many rows. Only 204 out of 891 rows have Cabin values.

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Bar Chart for Features

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Embarked')

# %% [markdown]
# ## Feature engineering

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Name and Title

# %%
train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: Title, dtype: int64

# %% [markdown]
# ### Family Survived?
# By default, 0.5. If survived 1 else 0. The matching is based on the "Last_Name" feature.

# %%
def survived_fams(df):
    # A function working on family survival rate using last names and ticket features
    df['Last_Name'] = df['Name'].apply(
        lambda df: str.split(df, ",")[0])
    
    # Adding new feature: 'Survived'
    default_survival_rate = 0.5
    df['Family_Survival'] = default_survival_rate
    
    for grp, grp_df in df[['Survived', 'Name', 'Last_Name', 'Fare', 'Ticket', 'PassengerId','SibSp', 'Parch', 'Age', 'Cabin']].groupby(['Last_Name', 'Fare']):
    
        if (len(grp_df) != 1):
            # A Family group is found.
            for ind, row in grp_df.iterrows():
                smax = grp_df.drop(ind)['Survived'].max()
                smin = grp_df.drop(ind)['Survived'].min()
                passID = row['PassengerId']
                if (smax == 1.0):
                    df.loc[df['PassengerId'] ==
                                  passID, 'Family_Survival'] = 1
                elif (smin == 0.0):
                    df.loc[df['PassengerId'] ==
                                  passID, 'Family_Survival'] = 0
    
    for _, grp_df in df.groupby('Ticket'):
        if (len(grp_df) != 1):
            for ind, row in grp_df.iterrows():
                if (row['Family_Survival'] == 0) | (
                        row['Family_Survival'] == 0.5):
                    smax = grp_df.drop(ind)['Survived'].max()
                    smin = grp_df.drop(ind)['Survived'].min()
                    passID = row['PassengerId']
                    if (smax == 1.0):
                        df.loc[df['PassengerId'] ==
                                      passID, 'Family_Survival'] = 1
                    elif (smin == 0.0):
                        df.loc[df['PassengerId'] ==
                                      passID, 'Family_Survival'] = 0
    
    
    return df

combined=pd.concat([train,test])
combined=survived_fams(combined)
train=combined.iloc[:len(train),:]
test=combined.iloc[len(train):,:]
train = train.drop(['Last_Name'], axis =1)
test = test.drop(['Survived', 'Last_Name'], axis =1)

# %%
#replacing all titles with mr, mrs, miss, master
def replace_titles(x):
    title=x['Title']
    if title in ['Countess','Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
        return 'Rare'
    elif title in ['Countess', 'Mme']:
        return 'Mrs'
    elif title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title =='Dr':
        if x['Sex']=='Male':
            return 'Mr'
        else:
            return 'Mrs'
    else:
        return title
    
train['Title']=train.apply(replace_titles, axis=1)
test['Title']=test.apply(replace_titles, axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_Survival
# 0      0         A/5 21171   7.2500   NaN        S    Mr              0.5
# 1      0          PC 17599  71.2833   C85        C   Mrs              0.5
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss              0.5
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title  Family_Survival
# 0  34.5      0      0   330911   7.8292   NaN        Q    Mr              0.5
# 1  47.0      1      0   363272   7.0000   NaN        S   Mrs              0.5
# 2  62.0      0      0   240276   9.6875   NaN        Q    Mr              0.5
# 3  27.0      0      0   315154   8.6625   NaN        S    Mr              0.5
# 4  22.0      1      1  3101298  12.2875   NaN        S   Mrs              1.0

# %%
bar_chart('Title')

# %% [markdown]
# ### Age

# %% [markdown]
# #### Some age is missing
# Let's use Title's media age for missing Age

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("mean"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("mean"), inplace=True)

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.00000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000      1
# 2                             Heikkinen, Miss. Laina  female  26.00000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000      1
# 4                           Allen, Mr. William Henry    male  35.00000      0
# 5                                   Moran, Mr. James    male  32.36809      0
# ...

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked Title  \
# ...

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()
# Out:
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ### Embarked

# %% [markdown]
# #### Filling missing values

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_Survival
# 0      0         A/5 21171   7.2500   NaN        S    Mr              0.5
# 1      0          PC 17599  71.2833   C85        C   Mrs              0.5
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss              0.5
# ...

# %% [markdown]
# ### Fare

# %%
# fill missing Fare with median fare for each Pclass
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("mean"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("mean"), inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_Survival
# 0      0         A/5 21171   7.2500   NaN        S    Mr              0.5
# 1      0          PC 17599  71.2833   C85        C   Mrs              0.5
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss              0.5
# ...

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()
# Out:
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_Survival
# 0      0         A/5 21171   7.2500   NaN        S    Mr              0.5
# 1      0          PC 17599  71.2833   C85        C   Mrs              0.5
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss              0.5
# ...

# %% [markdown]
# ### Cabin

# %%
train.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
# fill missing Cabin with 'Unknown'
train["Cabin"].fillna('Unknown', inplace=True)
test["Cabin"].fillna('Unknown', inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### Family size

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"]
test["FamilySize"] = test["SibSp"] + test["Parch"]

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# (0.0, 10.0)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked Title  Family_Survival  \
# 0      0         A/5 21171   7.2500  Unknown        S    Mr              0.5
# 1      0          PC 17599  71.2833      C85        C   Mrs              0.5
# 2      0  STON/O2. 3101282   7.9250  Unknown        S  Miss              0.5
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare    Cabin Embarked Title  \
# 0  34.5      0      0   330911   7.8292  Unknown        Q    Mr
# 1  47.0      1      0   363272   7.0000  Unknown        S   Mrs
# 2  62.0      0      0   240276   9.6875  Unknown        Q    Mr
# 3  27.0      0      0   315154   8.6625  Unknown        S    Mr
# 4  22.0      1      1  3101298  12.2875  Unknown        S   Mrs
#
#    Family_Survival  FamilySize
# 0              0.5           0
# 1              0.5           1
# ...

# %% [markdown]
# ### Fare manipulation
# Grouping fare

# %%
import numpy as np

def fare_grouping(x):
    # Ranging and grouping Fare using historical data
    bins = [-1, 7.91, 14.454, 31, 99, 250, np.inf]
    names = ['a', 'b','c', 'd', 'e', 'f']
    names = [1, 2, 3, 4, 5, 6]
    x['Fare_Bin'] = pd.cut(x['Fare'], bins ,labels=names).astype('int')
    dict_age={1 : 'a' , 2 : 'b' , 3 : 'c' , 4 : 'd' , 5: 'e' , 6 : 'f'}
    x['Fare_Bin']=x['Fare_Bin'].map(dict_age)
    return x

train = fare_grouping(train)
test = fare_grouping(test)

# %%
def is_alone(x):
    fam_list={False : 0 , True : 1}
    x['is_alone'] = (x['FamilySize']==0).map(fam_list)
    """visualization"""
    return x

def has_cabin(x):
    fam_list={False : 0 , True : 1}
    x['has_cabin'] = (x['Cabin']!='Unknown').map(fam_list)
    """visualization"""
    return x


def is_3stclass(x):
    class_list={False : 0 , True : 1}
    x['is_3rdclass'] = (x['Pclass']== 3 ).map(class_list)
    """visualization"""
    return x

train = is_alone(train)
train = has_cabin(train)
train = is_3stclass(train)
test = is_alone(test)
test = has_cabin(test)
test = is_3stclass(test)
train['Age*Class']=train['Age']*train['Pclass']
test['Age*Class']=test['Age']*test['Pclass']
train['Fare_Per_Person']=train['Fare']/(train['FamilySize']+1)
test['Fare_Per_Person']=test['Fare']/(test['FamilySize']+1)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


def age_grouping(x):
    
    k_data=pd.concat([x['Age'],x['Survived']],axis=1)
    k_data.rename( columns={ 0 :'Age' , 1 :'Survived'}, inplace=True )
    model = KMeans()
    sil = []
    for k in range(2, 9):
      kmeans = KMeans(n_clusters = k).fit(k_data)
      labels = kmeans.labels_
      sil.append(silhouette_score(k_data, labels, metric = 'euclidean'))
    plt_data=pd.concat([pd.Series(range(2,9)),pd.Series(sil)],axis=1)
    plt_data.rename( columns={ 0 :'clusters' , 1 :'silhouette scores'}, inplace=True )

    kmeans = KMeans(n_clusters=4, random_state=0).fit(k_data)
    labels_=kmeans.labels_
    k_data['age_grp']=labels_+1
    k_data['Passenger_Id']=x['PassengerId']
    
    agelist=[] 
    for i in range(0, 15):
        agelist.append('a')
    for i in range(15, 29):
        agelist.append('b')
    for i in range(29, 45): 
        agelist.append('c')
    for i in range(45, 90):
        agelist.append('d')
    age_dict={v: k for v, k in enumerate(agelist)}
    x['Age_Grp']=x['Age'].astype(int).map(age_dict)

    return x,age_dict

train,age_dict = age_grouping(train)
test['Age_Grp']=test['Age'].astype(int).map(age_dict)
# Out:
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\ivanv\Desktop\code\kaggle-titanic\.venv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# final features: pclass, sex, age, sibsp, parch, fare, embarked, deck(cabin), title, fam_size, fare_bin, age_grp, Fare_per_person, age*class, family_survival, is_alone, has_cabin, is_3class
features_drop = ['PassengerId','Name','Ticket']
train = train.drop(features_drop, axis=1)
test = test.drop(['Name','Ticket'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']
test_data = test.drop("PassengerId", axis=1).copy()
train_data.shape, target.shape
# Out:
# ((891, 18), (891,))

# %%
train_data
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare    Cabin Embarked Title  \
# 0         3    male  22.000000      1      0   7.2500  Unknown        S    Mr
# 1         1  female  38.000000      1      0  71.2833      C85        C   Mrs
# 2         3  female  26.000000      0      0   7.9250  Unknown        S  Miss
# 3         1  female  35.000000      1      0  53.1000     C123        S   Mrs
# 4         3    male  35.000000      0      0   8.0500  Unknown        S    Mr
# ..      ...     ...        ...    ...    ...      ...      ...      ...   ...
# 886       2    male  27.000000      0      0  13.0000  Unknown        S  Rare
# 887       1  female  19.000000      0      0  30.0000      B42        S  Miss
# 888       3  female  21.845638      1      2  23.4500  Unknown        S  Miss
# 889       1    male  26.000000      0      0  30.0000     C148        C    Mr
# 890       3    male  32.000000      0      0   7.7500  Unknown        Q    Mr
#
# ...

# %%
test_data
# Out:
#      Pclass     Sex        Age  SibSp  Parch      Fare    Cabin Embarked  \
# 0         3    male  34.500000      0      0    7.8292  Unknown        Q
# 1         3  female  47.000000      1      0    7.0000  Unknown        S
# 2         2    male  62.000000      0      0    9.6875  Unknown        Q
# 3         3    male  27.000000      0      0    8.6625  Unknown        S
# 4         3  female  22.000000      1      1   12.2875  Unknown        S
# ..      ...     ...        ...    ...    ...       ...      ...      ...
# 413       3    male  32.000000      0      0    8.0500  Unknown        S
# 414       1  female  39.000000      0      0  108.9000     C105        C
# 415       3    male  38.500000      0      0    7.2500  Unknown        S
# 416       3    male  32.000000      0      0    8.0500  Unknown        S
# 417       3    male   7.406471      1      1   22.3583  Unknown        C
#
#       Title  Family_Survival  FamilySize Fare_Bin  is_alone  has_cabin  \
# ...

# %%
import category_encoders as ce

# Define catboost encoder
cbe_encoder = ce.cat_boost.CatBoostEncoder()
  
# Fit encoder and transform the features
cbe_encoder.fit(train_data, target)
train_data = cbe_encoder.transform(train_data)

test_data = cbe_encoder.transform(test_data)

# %%
train_data.head(10)
# Out:
#    Pclass       Sex       Age  SibSp  Parch     Fare     Cabin  Embarked  \
# 0       3  0.189245  22.00000      1      0   7.2500  0.299977  0.337029
# 1       1  0.740901  38.00000      1      0  71.2833  0.383838  0.552567
# 2       3  0.740901  26.00000      0      0   7.9250  0.299977  0.337029
# 3       1  0.740901  35.00000      1      0  53.1000  0.461279  0.337029
# 4       3  0.189245  35.00000      0      0   8.0500  0.299977  0.337029
# 5       3  0.189245  32.36809      0      0   8.4583  0.299977  0.389536
# 6       1  0.189245  54.00000      0      0  51.8625  0.383838  0.337029
# 7       3  0.189245   2.00000      3      1  21.0750  0.299977  0.337029
# 8       3  0.740901  27.00000      0      2  11.1333  0.299977  0.337029
# 9       2  0.740901  14.00000      1      0  30.0708  0.299977  0.552567
#
#       Title  Family_Survival  FamilySize  Fare_Bin  is_alone  has_cabin  \
# 0  0.157112              0.5           1  0.198142         0          0
# ...

# %% [markdown]
# ## Modelling

# %%
# Importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pclass           891 non-null    int64
#  1   Sex              891 non-null    float64
#  2   Age              891 non-null    float64
#  3   SibSp            891 non-null    int64
#  4   Parch            891 non-null    int64
#  5   Fare             891 non-null    float64
#  6   Cabin            891 non-null    float64
#  7   Embarked         891 non-null    float64
#  8   Title            891 non-null    float64
#  9   Family_Survival  891 non-null    float64
#  10  FamilySize       891 non-null    int64
#  11  Fare_Bin         891 non-null    float64
#  12  is_alone         891 non-null    int64
#  13  has_cabin        891 non-null    int64
#  14  is_3rdclass      891 non-null    int64
#  15  Age*Class        891 non-null    float64
# ...

# %% [markdown]
# ### Cross Validation (K-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# ### KNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84444444 0.80898876 0.8988764  0.84269663 0.88764045 0.84269663
#  0.84269663 0.88764045 0.85393258 0.88764045]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 85.97

# %% [markdown]
# ### Decision Tree

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.88888889 0.82022472 0.8988764  0.85393258 0.8988764  0.85393258
#  0.86516854 0.8988764  0.80898876 0.91011236]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 86.98

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier(n_estimators=10)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.85555556 0.82022472 0.91011236 0.85393258 0.88764045 0.85393258
#  0.85393258 0.8988764  0.83146067 0.8988764 ]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 86.65

# %% [markdown]
# ### Naive Bayes

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.76404494 0.76404494 0.75280899 0.78651685 0.78651685
#  0.7752809  0.79775281 0.83146067 0.85393258]

# %%
# Naive Bayes Score
round(np.mean(score)*100, 2)
# Out:
# 79.12

# %% [markdown]
# ### SVM

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.87777778 0.82022472 0.8988764  0.84269663 0.88764045 0.85393258
#  0.85393258 0.88764045 0.85393258 0.88764045]

# %%
round(np.mean(score)*100,2)
# Out:
# 86.64

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LRC = LogisticRegression()
scoring = 'accuracy'
score = cross_val_score(LRC, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100,2)
# Out:
# [0.83333333 0.80898876 0.88764045 0.82022472 0.87640449 0.83146067
#  0.84269663 0.87640449 0.86516854 0.88764045]
# 85.3

# %% [markdown]
# ### XGboost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate=0.01 ,n_estimators=860,max_depth=3,subsample=1, colsample_bytree=1, gamma=6,reg_alpha = 14,reg_lambda = 3)
scoring = 'accuracy'
score = cross_val_score(xgb, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100,2)
# Out:
# [0.86666667 0.82022472 0.8988764  0.83146067 0.87640449 0.85393258
#  0.85393258 0.8988764  0.85393258 0.87640449]
# 86.31

# %% [markdown]
# ### Feature selection on xgboost since it is the most performant algorithm

# %%
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=xgb, step=1, cv=k_fold, scoring=scoring)
rfecv.fit(train_data, target)
#Selected features
print(str(train_data.columns[rfecv.get_support()]))
print("Optimal number of features : %d" % rfecv.n_features_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 5
#       3 rfecv.fit(train_data, target)
#       4 #Selected features
# ----> 5 print(str(train_data.columns[rfecv.get_support()]))
#       6 print("Optimal number of features : %d" % rfecv.n_features_)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
test_data = test_data[train_data.columns[rfecv.get_support()]]
train_data = train_data[train_data.columns[rfecv.get_support()]]

# %%
## Voting approach
from sklearn.ensemble import VotingClassifier
classifier_voting = VotingClassifier(estimators=[('XGB', xgb), ('LRC', LRC), ('RF',clf)])
scoring = 'accuracy'
score = cross_val_score(classifier_voting, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100,2)
# Out:
# [0.87777778 0.82022472 0.8988764  0.84269663 0.88764045 0.85393258
#  0.85393258 0.8988764  0.86516854 0.8988764 ]
# 86.98

# %%
classifier_voting.fit(train_data, target)
prediction = classifier_voting.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction.astype(int)
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         1
# 1          893         1
# 2          894         1
# 3          895         1
# 4          896         1
